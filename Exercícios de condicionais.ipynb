# %% [markdown]
# 1. Leia dois números, faça a soma e apresente caso seja maior que 15.

# %%
num1 = float(input("Digite o primeiro número:"))
num2 = float(input("Digite o segundo número:"))

resultado = num1 + num2

if resultado > 15:
  print("O número {} é maior que 15!".format(resultado))
# Out:
# Digite o primeiro número:10
# Digite o segundo número:6
# O número 16.0 é maior que 15!

# %% [markdown]
# 2. Faça um programa que recebendo um valor inteiro, informe se o número é positivo,
# negativo ou neutro.

# %%
num = int(input("Digite um número: "))

if num < 0:
  print("{} é um número negativo".format(num))
elif num == 0:
  print("{} é um número neutro".format(num))
else:
  print("{} é um número positivo".format(num))
# Out:
# Digite um número:-3
# -3 é um número negativo

# %% [markdown]
# 3. Leia a idade e informe se a pessoa é maior ou menor de idade

# %%
idade = int(input("Digite sua idade: "))

if idade > 17:
  print("Você é maior de idade!")
else:
  print("Você é menor de idade!")
# Out:
# Digite sua idade: 18
# Você é maior de idade!

# %% [markdown]
# 4. Faça um programa que pergunte a temperatura atual para o usuário e mostre uma
# mensagem na tela dizendo se está “quente”, “frio” ou “agradável”.

# %%
temperatura = float(input("Digite a temperatura atual: "))

if temperatura < 20:
  print("{}°C está frio!".format(temperatura))
elif temperatura > 25:
  print("{}°C está quente!".format(temperatura))
else:
  print("{}°C está agradável!".format(temperatura))
# Out:
# Digite a temperatura atual: 25.1
# 25.1°C está quente!

# %% [markdown]
# 5. Faça um programa em linguagem Python que leia dois números inteiros e informe
# se estes são iguais ou diferentes.

# %%
num1 = int(input("Digite o primeiro número: "))
num2 = int(input("Digite o segundo número: "))

if num1 == num2:
  print(f"{num1} é igual a {num2}")
else:
  print(f"{num1} é diferente de {num2}")
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 3
# 5 é diferente de 3

# %% [markdown]
# 6. Escreva um programa que verifique a validade de uma senha fornecida pelo
# usuário. A senha válida é o número 1234. Devem ser impressas as seguintes
# mensagens:
# - ACESSO PERMITIDO caso a senha seja válida.
# - ACESSO NEGADO caso a senha seja inválida.

# %%
senhaCerta = "1234"
senhaUsuario = input("Digite a senha para acesso: ")

if senhaUsuario == senhaCerta:
  print("ACESSO PERMITIDO!")
else:
  print("ACESSO NEGADO!")
# Out:
# Digite a senha para acesso: 1234
# ACESSO PERMITIDO

# %% [markdown]
# 7. Ler duas notas de um aluno, efetuar a média aritmética e, se a média for maior ou
# igual a 7, informar que o aluno foi aprovado; se a média for maior ou igual a 5 mas
# menor do que 7, informar que o aluno está de exame; se a média for menor do que
# 5 informar que o aluno foi reprovado

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

media = (num1 + num2) / 2

if media >= 7:
  print(f"Você está aprovado com a nota {media}!")
elif 5 <= media < 7:
  print(f"Você está de exame com a nota {media}!")
else:
  print(f"Você está reprovado com a nota {media}!")
# Out:
# Digite o primeiro número: 4
# Digite o segundo número: 4
# Você está reprovado com a nota 4.0!

# %% [markdown]
# 8. Desenvolva um programa que recebe do usuário o placar de um jogo de futebol (os
# gols de cada time) e informe se o resultado foi um empate, se a vitória foi do
# primeiro time ou do segundo time.

# %%
gTime1 = int(input("Digite os gols do primeiro time: "))
gTime2 = int(input("Digite os gols do segundo time: "))

if gTime1 > gTime2:
  print(f"O Time 1 ganhou de {gTime1} gol(s) a {gTime2} gol(s) do Time 2")
elif gTime1 == gTime2:
  print(f"Os dois times empataram com o placar de {gTime1} x {gTime2}")
else:
  print(f"O Time 2 ganhou de {gTime2} gol(s) a {gTime1} gol(s) do Time 1")

# %% [markdown]
# 9. Faça um Programa que pergunte em que turno você estuda. Peça para digitar Mmatutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa
# Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
turno = input("Digite em que turno você estuda: ")

if turno == "M" or turno == "m":
  print("Bom Dia!")
elif turno == "V" or turno == "v":
  print("Boa Tarde!")
elif turno == "N" or turno == "n":
  print("Boa Noite!")
else:
  print("Valor Inválido!")

# %% [markdown]
# 10. Faça um programa que solicite ao usuário sua idade, depois disso, exiba a
# classificação etária de acordo com as faixas de valores:
# - Criança para 0 até 11 anos;
# - Adolescente para 12 até 18 anos;
# - Jovem para 19 até 24 anos;
# - Adulto para 25 até 40 anos;
# - Meia Idade para 41 até 60 anos;
# - Idoso acima de 60 anos.

# %%
idade = int(input("Digite sua idade: "))

if idade < 0:
  print("Inexistente")
elif 0 <= idade <= 11:
  print("Criança")
elif 12 <= idade <= 18:
  print("Adolescente")
elif 19 <= idade <= 24:
  print("Jovem")
elif 25 <= idade <= 40:
  print("Adulto")
elif 41 <= idade <= 60:
  print("Meia Idade")
else:
  print("Idoso")
# Out:
# Digite sua idade: 66
# Idoso

# %% [markdown]
# 11. As Organizações Tabajara resolveram dar um aumento de salário aos seus
# colaboradores e lhe contrataram para desenvolver o programa que calculará os
# reajustes. Faça um programa que recebe o salário de um colaborador e o reajuste
# segundo o seguinte critério, baseado no salário atual:
# - salários até RS 280,00 (incluindo) = aumento de 20%
# - salários entre RS 280,00 e RS 700,00 : aumento de 15%
# - salários entre RS 700,00 e RS 1500,00 : aumento de 10%
# - salários de RS 1500,00 em diante : aumento de 5%
#
# Após o aumento ser realizado, informe na tela:
# - o salário antes do reajuste;
# - o percentual de aumento aplicado;
# - o valor do aumento;
# - o novo salário, após o aumento.

# %%
salario = float(input("Digite seu salário: "))
salarioNovo = salario

if salario <= 280:
  aumento = salario * 0.2
  salarioNovo = salario + salario * 0.2
  print(f"Seu salário atual é de {salario} e seu novo salário com aumento de 20%({aumento}) é de {salarioNovo}")
elif 280 < salario <= 700:
  aumento = salario * 0.15
  salarioNovo = salario + salario * 0.15
  print(f"Seu salário atual é de {salario} e seu novo salário com aumento de 15%({aumento}) é de {salarioNovo}")
elif 700 < salario <= 1500:
  aumento = salario * 0.1
  salarioNovo = salario + salario * 0.1
  print(f"Seu salário atual é de {salario} e seu novo salário com aumento de 10%({aumento}) é de {salarioNovo}")
else:
  aumento = salario * 0.05
  salarioNovo = salario + salario * 0.05
  print(f"Seu salário atual é de {salario} e seu novo salário com aumento de 5%({aumento}) é de {salarioNovo}")
# Out:
# Digite seu salário: 2000
# Seu salário atual é de 2000.0 e seu novo salário com aumento de 5%(100.0) é de 2100.0

# %% [markdown]
# 12. Faça um Programa que leia um número e exiba o dia correspondente da semana.
# (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

# %%
num = int(input("Digite um número: "))

if num == 1:
  print("Domingo")
elif num == 2:
  print("Segunda")
elif num == 3:
  print("Terça")
elif num == 4:
  print("Quarta")
elif num == 5:
  print("Quinta")
elif num == 6:
  print("Sexta")
elif num == 7:
  print("Sábado")
else:
  print("Valor inválido")
# Out:
# Digite um número: 8
# Valor inválido

# %% [markdown]
# 13. Faça um programa que pergunte ao usuário se ele quer passar uma temperatura de
# Fahrenheit para Celsius ou de Celsius para Fahrenheit, e que, a partir da resposta
# do usuário, faça a devida conversão.

# %%
escolha = input("Bem-Vindo ao conversor de temperaturas!\nC - converter de Celsius para Fahrenheit\nF - converter de Fahrenheit para Celsius\n> ")

if escolha == "f" or escolha == "F":
  fahrenheit = float(input("\nDigite a temperatura em Fahrenheit: "))
  celsius = (fahrenheit - 32) * 5/9
  print(f"\n{fahrenheit}°F é igual a {celsius}°C")
elif escolha == "c" or escolha =="C":
  celsius = float(input("\nDigite a temperatura em Celsius: "))
  fahrenheit = (celsius * 9/5) + 32
  print(f"\n{celsius}°C é igual a {fahrenheit}°F")
else:
  print("Escolha inválida")
# Out:
# Bem-Vindo ao conversor de temperaturas!
# C - converter de Celsius para Fahrenheit
# F - converter de Fahrenheit para Celsius
# > C
#
# Digite a temperatura em Celsius: 32
#
# 32.0°C é igual a 89.6°F

# %% [markdown]
# 14. Faça um programa que receba a idade de uma pessoa e imprima sua condição
# (obrigatória, optativa ou proibida), em relação ao ato de votar, conforme
# apresentado abaixo:
# - Pessoas com idade menor que 16 anos são proibidas de votar (proibido);
# - Pessoas com idade igual a 16 e menor que 18 anos não são obrigadas a votar
# (optativo);
# - Pessoas com idade igual a 18 e menor que 65 anos são obrigadas a votar
# (obrigatório);
# - Pessoas com idade igual ou maior a 65 anos não são obrigadas a votar (optativo)

# %%
idade = int(input("Digite a sua idade: "))

if idade < 16:
  print("Você é proibido de votar! ")
elif 16 <= idade < 18:
  print("Seu voto é optativo!")
elif 18 <= idade < 65:
  print("Seu voto é OBRIGATÓRIO!")
else:
  print("Seu voto é optativo!")
# Out:
# Digite a sua idade: 65
# Seu voto é optativo!

# %% [markdown]
# 15. Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As
# perguntas são:
# - “Telefonou para a vítima? “
# - “Esteve no local do crime?”
# - “Mora perto da vítima? “
# - “Devia para a vítima? “
# - “Já trabalhou com a vítima? “

# %%
sim = 0
reposta1 = input("Telefonou para a vítima? s/n\n> ")
if reposta1 == "s" or reposta1 == "S":
  sim += 1
reposta2 = input("Esteve no local do crime? s/n\n> ")
if reposta2 == "s" or reposta2 == "S":
  sim += 1
reposta3 = input("Mora perto da vítima? s/n\n> ")
if reposta3 == "s" or reposta3 == "S":
  sim += 1
reposta4 = input("Devia para a vítima? s/n\n> ")
if reposta4 == "s" or reposta4 == "S":
  sim += 1
reposta5 = input("Já trabalhou com a vítima? s/ns\n> ")
if reposta5 == "s" or reposta5 == "S":
  sim += 1

if sim == 2:
  print("Você é um dos nossos suspeitos!")
elif sim == 3 or sim == 4:
  print("Você é um dos cumplíces está preso tudo que for falado podera e será usado contra você!")
elif sim == 5:
  print("Você é o assasino está preso tudo que for falado podera e será usado contra você!")
else:
  print("Você é inocente obrigado pela colaboração!")
# Out:
# Telefonou para a vítima? s/n
# >s
# Esteve no local do crime? s/n
# >s
# Mora perto da vítima? s/n
# >s
# Devia para a vítima? s/n
# >s
# Já trabalhou com a vítima? s/ns
# >s
# Você é o assasino está preso tudo que for falado podera e será usado contra você!

# %% [markdown]
# 16. Faça um programa que pergunte o preço de três produtos e informe qual produto
# você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
produto1 = float(input("Digite o valor do primeiro produto: "))
produto2 = float(input("Digite o valor do segundo produto: "))
produto3 = float(input("Digite o valor do terceiro produto: "))

if produto1 > produto2 < produto3:
  print(f"\nLeve o segundo produto no valor de R${produto2} ta super barato!")
elif produto2 > produto1 < produto3:
  print(f"\nLeve o primeiro produto no valor de R${produto1} ta super barato!")
else:
  print(f"\nLeve o terceiro produto no valor de R${produto3} ta super barato!")
# Out:
# Digite o valor do primeiro produto: 15
# Digite o valor do segundo produto: 10
# Digite o valor do terceiro produto: 15
# Leve o segundo produto no valor de R$10.0 ta super barato!
